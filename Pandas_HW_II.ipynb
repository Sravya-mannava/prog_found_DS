# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravya-mannava/prog_found_DS/blob/main/Pandas_HW_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas Homework II
#
# 20 points (1 pt for each task except for task 0)
#
# Due by midnight October 27, 2023
#
# We will be using the Failed Bank List from FDIC. Just follow along and complete the tasks outlined below. Most of the tasks can be solved in different ways. The tasks will get harder and harder as you go along.
#
# **To avoid erasing the sample output, please insert a new cell above the sample output**. Write your script inside the new cell and run. Verify your output with the sample output
#
# For lab submission, please rename your file using the following format
#
# `firstname_familyname_pandas_HW2.ipynb`

# %%
# please enter your name and 700# in this cell
#Name: Sravya Mannava
#700 : 700747750

# %% [markdown]
# ### Task 0 (0 pt)
# Run the following cell

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ### Task 1
# **Import numpy as np** <br> **Import pandas as pd**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 2
# Read the failed bank list from FDIC website at https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/ <br>
# Display the first five rows of the table

# %%
df = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
df[0].head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart      KS     25851
# 1       First Republic Bank  San Francisco      CA     59017
# 2            Signature Bank       New York      NY     57053
# 3       Silicon Valley Bank    Santa Clara      CA     24735
# 4         Almena State Bank         Almena      KS     15426
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0               Dream First Bank, N.A.       July 28, 2023     10544
# 1            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 2                  Flagstar Bank, N.A.      March 12, 2023     10540
# 3  First–Citizens Bank & Trust Company      March 10, 2023     10539
# 4                          Equity Bank    October 23, 2020     10538

# %%
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart      KS     25851
# 1       First Republic Bank  San Francisco      CA     59017
# 2            Signature Bank       New York      NY     57053
# 3       Silicon Valley Bank    Santa Clara      CA     24735
# 4         Almena State Bank         Almena      KS     15426
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0               Dream First Bank, N.A.       July 28, 2023     10544
# 1            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 2                  Flagstar Bank, N.A.      March 12, 2023     10540
# 3  First–Citizens Bank & Trust Company      March 10, 2023     10539
# 4                          Equity Bank    October 23, 2020     10538

# %% [markdown]
# ### Task 3
# Display the Column names of the table

# %%
df[0].columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %% [markdown]
# ### Task 4
# Check to see whether there is any empty values in each column

# %%
df[0].isnull().any()
# Out:
# Bank NameBank              False
# CityCity                   False
# StateSt                    False
# CertCert                   False
# Acquiring InstitutionAI    False
# Closing DateClosing        False
# FundFund                   False
# dtype: bool

# %%
# Out:
# Bank NameBank              False
# CityCity                   False
# StateSt                    False
# CertCert                   False
# Acquiring InstitutionAI    False
# Closing DateClosing        False
# FundFund                   False
# dtype: bool

# %% [markdown]
# ### Task 5
# Check to see whether there is any duplicated row

# %%
df[0].duplicated().sum()
# Out:
# 0

# %%
# Out:
# 0

# %% [markdown]
# ### Task 6
#
# You may notice that the column names of the table is not correct. Please change some of the column names accoording to the following list. <br>
# `Bank NameBank` -> `Bank Name` <br>
# `CityCity` -> `City` <br>
# `StateSt` -> `State` <br>
# `Closing DateClosing` -> `Closing Date`

# %%
df[0] = df[0].rename(columns={'Bank NameBank': 'Bank Name', 'CityCity': 'City','StateSt':'State','Closing DateClosing':'Closing Date'})
df[0].head()
# Out:
#                   Bank Name           City State  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart    KS     25851
# 1       First Republic Bank  San Francisco    CA     59017
# 2            Signature Bank       New York    NY     57053
# 3       Silicon Valley Bank    Santa Clara    CA     24735
# 4         Almena State Bank         Almena    KS     15426
#
#                Acquiring InstitutionAI      Closing Date  FundFund
# 0               Dream First Bank, N.A.     July 28, 2023     10544
# 1            JPMorgan Chase Bank, N.A.       May 1, 2023     10543
# 2                  Flagstar Bank, N.A.    March 12, 2023     10540
# 3  First–Citizens Bank & Trust Company    March 10, 2023     10539
# 4                          Equity Bank  October 23, 2020     10538

# %%
# Out:
#                   Bank Name           City State  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart    KS     25851
# 1       First Republic Bank  San Francisco    CA     59017
# 2            Signature Bank       New York    NY     57053
# 3       Silicon Valley Bank    Santa Clara    CA     24735
# 4         Almena State Bank         Almena    KS     15426
#
#                Acquiring InstitutionAI      Closing Date  FundFund
# 0               Dream First Bank, N.A.     July 28, 2023     10544
# 1            JPMorgan Chase Bank, N.A.       May 1, 2023     10543
# 2                  Flagstar Bank, N.A.    March 12, 2023     10540
# 3  First–Citizens Bank & Trust Company    March 10, 2023     10539
# 4                          Equity Bank  October 23, 2020     10538

# %% [markdown]
# ### Task 7
# How many failed banks were based in Missouri?

# %%
len(df[0][df[0].State =='MO'])
# Out:
# 16

# %%
# Out:
# 16

# %% [markdown]
# ### Task 8
# Which city has the most numbers of failed banks?

# %%
df[0]['City'].value_counts().index[0]
# Out:
# 'Chicago'

# %%
df['City'].value_counts().index[0]
# Out:
# 'Chicago'

# %% [markdown]
# ### Task 9
# Verify the date in the 'Closing Date' column is a String not the DateTime object

# %%
type(df[0]['Closing Date'][0])
# Out:
# str

# %%
# Out:
# str

# %% [markdown]
# ### Task 10
# Which year has the most failed banks?

# %%
year_df=pd.DataFrame(i.year for i in pd.to_datetime(df[0]['Closing Date']))
str(year_df.value_counts().index[0][0])
# Out:
# '2010'

# %%
# Out:
# '2010'

# %% [markdown]
# ### Task 11
# Which month has the most failed banks?

# %%
month_df=pd.DataFrame(i.month_name() for i in pd.to_datetime(df[0]['Closing Date']))
str(month_df.value_counts().index[0][0])
# Out:
# 'July'

# %%
# Out:
# 'July'

# %% [markdown]
# ### Task 12
# Which institution acquired the second most numbers of failed banks?

# %%
df[0]['Acquiring InstitutionAI'].value_counts().index[1]
# Out:
# 'State Bank and Trust Company'

# %%
# Out:
# 'State Bank and Trust Company'

# %% [markdown]
# ### Task 13
# Change the date in the `Closing Date` column to the dateTime object and display the first five rows of the table.

# %%
df[0]['Closing Date']=pd.to_datetime(df[0]['Closing Date'])
df[0].head()
# Out:
#                   Bank Name           City State  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart    KS     25851
# 1       First Republic Bank  San Francisco    CA     59017
# 2            Signature Bank       New York    NY     57053
# 3       Silicon Valley Bank    Santa Clara    CA     24735
# 4         Almena State Bank         Almena    KS     15426
#
#                Acquiring InstitutionAI Closing Date  FundFund
# 0               Dream First Bank, N.A.   2023-07-28     10544
# 1            JPMorgan Chase Bank, N.A.   2023-05-01     10543
# 2                  Flagstar Bank, N.A.   2023-03-12     10540
# 3  First–Citizens Bank & Trust Company   2023-03-10     10539
# 4                          Equity Bank   2020-10-23     10538

# %%
# Out:
#                   Bank Name           City State  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart    KS     25851
# 1       First Republic Bank  San Francisco    CA     59017
# 2            Signature Bank       New York    NY     57053
# 3       Silicon Valley Bank    Santa Clara    CA     24735
# 4         Almena State Bank         Almena    KS     15426
#
#                Acquiring InstitutionAI Closing Date  FundFund
# 0               Dream First Bank, N.A.   2023-07-28     10544
# 1            JPMorgan Chase Bank, N.A.   2023-05-01     10543
# 2                  Flagstar Bank, N.A.   2023-03-12     10540
# 3  First–Citizens Bank & Trust Company   2023-03-10     10539
# 4                          Equity Bank   2020-10-23     10538

# %% [markdown]
# ### Task 14
# Display the Bank information which has a cert number 33901

# %%
df[0][df[0]['CertCert']==33901]
# Out:
#              Bank Name         City State  CertCert  \
# 537  ANB Financial, NA  Bentonville    AR     33901
#
#             Acquiring InstitutionAI Closing Date  FundFund
# 537  Pulaski Bank and Trust Company   2008-05-09     10005

# %%
# Out:
#              Bank Name         City State  CertCert  \
# 537  ANB Financial, NA  Bentonville    AR     33901
#
#             Acquiring InstitutionAI Closing Date  FundFund
# 537  Pulaski Bank and Trust Company   2008-05-09     10005

# %% [markdown]
# ### Task 15
# How many banks failed between January 1, 2008 and December 31, 2010?

# %%
len(df[0][df[0]['Closing Date'].between('2008-01-01', '2010-12-31')])
# Out:
# 322

# %%
# Out:
# 322

# %% [markdown]
# ### Task 16
# Reorganize the table to make the State and City as the indexes of the table. Display the first 20 rows of the new table

# %%
df[0]=df[0].set_index(['State', 'City']).sort_index()
df[0].head(20)
# Out:
#                                                    Bank Name  CertCert  \
# State City
# AL    Birmingham                               Superior Bank     17750
#       Birmingham                                 Nexity Bank     19794
#       Mulberry                                   Allied Bank        91
# AZ    Flagstaff                             First State Bank     34875
#       Gilbert               Union Bank, National Association     34485
#       Gold Canyon                           Gold Canyon Bank     58066
#       Mesa                             Towne Bank of Arizona     57697
#       Mesa                         Valley Capital Bank, N.A.     58399
#       Phoenix                        Sunrise Bank of Arizona     34707
#       Phoenix                          Western National Bank     57917
#       Phoenix                              Desert Hills Bank     57060
#       Phoenix                                 Bank USA, N.A.     32218
#
#                                         Acquiring InstitutionAI Closing Date  \
# State City
# AL    Birmingham            Superior Bank, National Association   2011-04-15
#       Birmingham                       AloStar Bank of Commerce   2011-04-15
#       Birmingham                                     IBERIABANK   2009-08-21
#       Fort Deposit                          First Citizens Bank   2010-03-19
#       Irondale                                        Beal Bank   2009-12-18
#       Montgomery         Branch Banking & Trust Company, (BB&T)   2009-08-14
#       Sylacauga                            Southern States Bank   2012-05-18
# AR    Batesville                                  Southern Bank   2010-12-17
#       Bentonville                Pulaski Bank and Trust Company   2008-05-09
#       Gravette                               Delta Trust & Bank   2001-09-07
#       Mulberry                                     Today's Bank   2016-09-23
# AZ    Flagstaff                                    Sunwest Bank   2009-09-04
#       Gilbert                                     MidFirst Bank   2009-08-14
#       Gold Canyon   First Scottsdale Bank, National Association   2013-04-05
#       Mesa                             Commerce Bank of Arizona   2010-05-07
#       Mesa                              Enterprise Bank & Trust   2009-12-11
#       Phoenix         First Fidelity Bank, National Association   2013-08-23
#       Phoenix                                Washington Federal   2011-12-16
#       Phoenix                           New York Community Bank   2010-03-26
#       Phoenix                                    U.S. Bank N.A.   2009-10-30
#
#                     FundFund
# State City
# AL    Birmingham       10358
#       Birmingham       10356
#       Birmingham       10106
#       Fort Deposit     10204
#       Irondale         10163
#       Montgomery       10103
#       Sylacauga        10440
# AR    Batesville       10322
#       Bentonville      10005
#       Gravette          4649
#       Mulberry         10522
# AZ    Flagstaff        10114
#       Gilbert          10102
#       Gold Canyon      10472
#       Mesa             10235
#       Mesa             10159
#       Phoenix          10487
#       Phoenix          10416
#       Phoenix          10205
#       Phoenix          10136

# %% [markdown]
# ### Task 17
# Display failed banks based in Kansas City, MO

# %%
df[0].loc[('MO','Kansas City')]
# Out:
#                                    Bank Name  CertCert  \
# State City
# MO    Kansas City  First Bank of Kansas City     25231
#       Kansas City     Douglass National Bank     24660
#
#                           Acquiring InstitutionAI Closing Date  FundFund
# State City
# MO    Kansas City             Great American Bank   2009-09-04     10112
#       Kansas City  Liberty Bank and Trust Company   2008-01-25     10003

# %%
# Out:
#                                    Bank Name  CertCert  \
# State City
# MO    Kansas City  First Bank of Kansas City     25231
#       Kansas City     Douglass National Bank     24660
#
#                           Acquiring InstitutionAI Closing Date  FundFund
# State City
# MO    Kansas City             Great American Bank   2009-09-04     10112
#       Kansas City  Liberty Bank and Trust Company   2008-01-25     10003

# %% [markdown]
# ### Task 18
# Display failed banks in Missouri and Kansas

# %%
df[0].loc[['MO','KS']]
# Out:
#       Overland Park       4731                     Arvest Bank   2009-12-11
#       Paola               4754             Great Southern Bank   2009-03-20
#       Sylvan Grove       10506       The Bennington State Bank   2010-07-23
#       Topeka             22728           Citizens Bank & Trust   2008-08-22
#
#                       FundFund
# State City
# MO    Butler             10225
#       Chesterfield       10299
#       Creve Coeur        10227
#       Ellington          10400
#       Glasgow            10449
#       Hume               10004
#       Jefferson City     10297
#       Kansas City        10112
#       Kansas City        10003
#       Leeton             10174
#       Sedalia            10460
#       Springfield        10239
#       St. Louis          10458
#       St. Louis          10146
#       Sugar Creek        10052
#       Sunrise Beach      10467
# KS    Almena             10538
#       Anthony            10066
#       Argonia            10529
#       Elkhart            10544
#       Leawood            10452
#       Olathe             10388
#       Olathe             10298
#       Overland Park      10302
#       Overland Park      10160
#       Paola              10046
#       Sylvan Grove       10269
#       Topeka             10011

# %% [markdown]
# ### Task 19
# Display failed banks based in the Kansas City metro area which include Kansas City, Overland Park, Leawood and Olathe

# %%
df[0].loc[[('MO','Kansas City'),('KS','Overland Park'),('KS','Leawood'),('KS','Olathe')]]
# Out:
#                                              Bank Name  CertCert  \
# State City
# MO    Kansas City            First Bank of Kansas City     25231
#       Kansas City               Douglass National Bank     24660
# KS    Overland Park                     Hillcrest Bank     22173
#       Overland Park                      SolutionsBank      4731
#       Leawood                           Heartland Bank      1361
#       Olathe         The First National Bank of Olathe      4744
#       Olathe             Security Savings Bank, F.S.B.     30898
#
#                             Acquiring InstitutionAI Closing Date  FundFund
# State City
# MO    Kansas City               Great American Bank   2009-09-04     10112
#       Kansas City    Liberty Bank and Trust Company   2008-01-25     10003
# KS    Overland Park            Hillcrest Bank, N.A.   2010-10-22     10302
#       Overland Park                     Arvest Bank   2009-12-11     10160
#       Leawood                          Metcalf Bank   2012-07-20     10452
#       Olathe                Enterprise Bank & Trust   2011-08-12     10388
#       Olathe            Simmons First National Bank   2010-10-15     10298

# %%
# Out:
#                                              Bank Name  CertCert  \
# State City
# MO    Kansas City            First Bank of Kansas City     25231
#       Kansas City               Douglass National Bank     24660
# KS    Overland Park                     Hillcrest Bank     22173
#       Overland Park                      SolutionsBank      4731
#       Leawood                           Heartland Bank      1361
#       Olathe         The First National Bank of Olathe      4744
#       Olathe             Security Savings Bank, F.S.B.     30898
#
#                             Acquiring InstitutionAI Closing Date  FundFund
# State City
# MO    Kansas City               Great American Bank   2009-09-04     10112
#       Kansas City    Liberty Bank and Trust Company   2008-01-25     10003
# KS    Overland Park            Hillcrest Bank, N.A.   2010-10-22     10302
#       Overland Park                     Arvest Bank   2009-12-11     10160
#       Leawood                          Metcalf Bank   2012-07-20     10452
#       Olathe                Enterprise Bank & Trust   2011-08-12     10388
#       Olathe            Simmons First National Bank   2010-10-15     10298

# %% [markdown]
# ### Task 20
# How many failed banks' names include the word `National`?

# %%
len(df[0][df[0]['Bank Name'].str.contains('National')])
# Out:
# 69

# %%
# Out:
# 69
